# %%
from cobra.io import read_sbml_model
from cobra import Reaction, Metabolite

# Read model (model of Escherichia coli)
model_1 = read_sbml_model('iML1515.xml')

# %%
model_1.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ec_iML1515_core_75p37M = 0.8769972144269709</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.004565</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>2.192E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.0006218</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.01409</td>
# ...

# %%
#model.reactions.DM_4crsol_c
# p-Cresol leaving the system

# %%
#model.metabolites.get_by_id('4crsol_c')
# only other reaction is TYRL, so maybe knock that one out?

# %%
#model.reactions.DM_5drib_c
# 5'-deoxyribose to leaving the system

# %%
#model.reactions.DM_amob_c

# %%
model_2 = read_sbml_model('model_atocopherol.xml')

# %%
model_2.objective = model.reactions.DM_avite1_c

# %%
with model_2:
    model_2.reactions.BIOMASS_Ec_iML1515_core_75p37M.lower_bound = 0.44
    summary = model_2.summary()
summary
# Out:
# <h3>Objective</h3><p>1.0 DM_avite1_c = 0.6133904007420902</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.00229</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.00229</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>1.1E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.000312</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.007067</td>
#       <td>0</td>
# ...

# %%
model_3 = read_sbml_model('model_atocopherol_tyr.xml')

# %%
model_3.objective = model.reactions.DM_avite1_c

# %%
with model_3:
    model_3.reactions.BIOMASS_Ec_iML1515_core_75p37M.lower_bound = 0.44
    summary = model_3.summary()
summary
# Out:
# <h3>Objective</h3><p>1.0 DM_avite1_c = 0.7989720203366969</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ca2_e</td>
#       <td>EX_ca2_e</td>
#       <td>0.00229</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cl_e</td>
#       <td>EX_cl_e</td>
#       <td>0.00229</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cobalt2_e</td>
#       <td>EX_cobalt2_e</td>
#       <td>1.1E-05</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cu2_e</td>
#       <td>EX_cu2_e</td>
#       <td>0.000312</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>fe2_e</td>
#       <td>EX_fe2_e</td>
#       <td>0.007067</td>
#       <td>0</td>
# ...
